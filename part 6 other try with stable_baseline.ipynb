# %% [markdown]
# ## This part uses rl methods from stable_baseline pacakage without details of implements

# %%
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import PPO
import matplotlib.pyplot as plt
import os
import gym
import tensorflow as tf

import preprocess_env3_8features
import preprocessing_adding_technical_indicator

import pandas as pd
import numpy as np
import random
import tensorflow as tf
from tensorflow import keras

# %%
df = preprocessing_adding_technical_indicator.add_technical_indicator()
env = preprocess_env3_8features.StockEnv(df)
# Out:
# [ 1.00000e+03  0.00000e+00  0.00000e+00  2.62000e+02  0.00000e+00
#  -6.66667e+01  4.69697e+01  3.16346e+05]

# %%
model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=500000)
# Out:
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.04e+03    |
# |    ep_rew_mean          | -466        |
# | time/                   |             |
# |    fps                  | 820         |
# |    iterations           | 1           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.004804611 |
# |    clip_fraction        | 0.0534      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 383         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00276    |
# |    value_loss           | 748         |
# -----------------------------------------
# ------------------------------------------
# ...

# %%
obs = env.reset()
for i in range(2100):
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)

# %%
env.money_memory
# Out:
# [1000,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
# ...

# %% [markdown]
# After many iterations, the result is converge to remain the initial money.

# %%
import gym
from stable_baselines3 import A2C

model2 = A2C("MlpPolicy", env, verbose=1)
model2.learn(total_timesteps=500000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 614          |
# |    iterations           | 100          |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 500          |
# | train/                  |              |
# |    approx_kl            | 0.0021218508 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0007       |
# |    loss                 | 0.064        |
# |    n_updates            | 99           |
# |    policy_gradient_loss | -0.000838    |
# |    policy_loss          | 1.51         |
# |    value_loss           | 116          |
# ------------------------------------------
# -------------------------------------
# ...

# %%
obs = env.reset()
for i in range(2100):
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
